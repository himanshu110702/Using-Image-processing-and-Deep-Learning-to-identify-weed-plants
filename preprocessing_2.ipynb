# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
#import keras
import os
from tqdm import tqdm
import json
import warnings
warnings.filterwarnings('ignore')

# %%
train_json = r"C:/Users/Ashwaq Ahmed/Documents/pythoncode/MAjor/pythonProject2/train.json"
test_json = r"C:/Users/Ashwaq Ahmed/Documents/pythoncode/MAjor/pythonProject2/test.json"
images_path = r"C:/Users/Ashwaq Ahmed/Documents/pythoncode/MAjor/pythonProject2/agri_data_img/"

# %%
with open(train_json,'r') as train:
    train_data = json.load(train)

# %%
with open(test_json,'r') as test:
    test_data = json.load(test)

# %%
train_images_list = list(train_data.keys())
test_images_list =list(test_data.keys())

# %% [markdown]
# #### Making Folders

# %%
os.mkdir('Train')
os.mkdir('Test')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.mkdir('Train')
#       2 os.mkdir('Test')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Train'

# %%
os.mkdir('Train/weed')
os.mkdir('Train/crop')
os.mkdir('Train/background')

os.mkdir('Test/weed')
os.mkdir('Test/crop')
os.mkdir('Test/background')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 os.mkdir('Train/weed')
#       2 os.mkdir('Train/crop')
#       3 os.mkdir('Train/background')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Train/weed'

# %% [markdown]
# #### Generating Images for training

# %%
for count,img_id in tqdm(enumerate(train_images_list)):
    img = cv2.imread(images_path + img_id)
    
    
    for proposal in train_data[img_id]['region_proposal']:
        x,y,w,h = proposal[0]
        label   = proposal[1]
         
        temp_img = cv2.cvtColor(cv2.resize(img[y:y+h,x:x+w,:],(224,224)),cv2.COLOR_BGR2RGB)
        
        cv2.imwrite('Train/'+label+'/'+ label+'_'+ str(len(os.listdir('Train/'+label))) +'.jpeg',temp_img)
        
    
    for background in train_data[img_id]['negative_example']:
        x,y,w,h = background
        label = 'background'
        
        temp_img = cv2.cvtColor(cv2.resize(img[y:y+h,x:x+w,:],(224,224)),cv2.COLOR_BGR2RGB)
        
        cv2.imwrite('Train/'+label+'/'+ label+'_'+ str(len(os.listdir('Train/'+label))) + '.jpeg',temp_img)
# Out:
# 8it [00:44,  5.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 20
#      16 label = 'background'
#      18 temp_img = cv2.cvtColor(cv2.resize(img[y:y+h,x:x+w,:],(224,224)),cv2.COLOR_BGR2RGB)
# ---> 20 cv2.imwrite('Train/'+label+'/'+ label+'_'+ str(len(os.listdir('Train/'+label))) + '.jpeg',temp_img)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Generating Images for Testing

# %%
for count,img_id in tqdm(enumerate(test_images_list)):
    img = cv2.imread(images_path + img_id)
    
    
    for proposal in test_data[img_id]['region_proposal']:
        x,y,w,h = proposal[0]
        label   = proposal[1]
         
        temp_img = cv2.cvtColor(cv2.resize(img[y:y+h,x:x+w,:],(224,224)),cv2.COLOR_BGR2RGB)
        
        cv2.imwrite('Test/'+label+'/'+ label+'_'+ str(len(os.listdir('Test/'+label))) +'.jpeg',temp_img)
        
    
    for background in test_data[img_id]['negative_example']:
        x,y,w,h = background
        label = 'background'
        
        temp_img = cv2.cvtColor(cv2.resize(img[y:y+h,x:x+w,:],(224,224)),cv2.COLOR_BGR2RGB)
        
        cv2.imwrite('Test/'+label+'/'+ label+'_'+ str(len(os.listdir('Test/'+label))) + '.jpeg',temp_img)
# Out:
# 1it [00:00,  2.23it/s]

# %%
print('Total training weed images are {}'.format(len(os.listdir('Train/weed'))))
print('Total training crop images are {}'.format(len(os.listdir('Train/crop'))))
print('Total training background images are {}'.format(len(os.listdir('Train/background'))))
# Out:
# Total training weed images are 7722
# Total training crop images are 10298
# Total training background images are 35350

# %%
print('Total testing weed images are {}'.format(len(os.listdir('Test/weed'))))
print('Total testing crop images are {}'.format(len(os.listdir('Test/crop'))))
print('Total testing background images are {}'.format(len(os.listdir('Test/background'))))
# Out:
# Total testing weed images are 2332
# Total testing crop images are 3147
# Total testing background images are 10771

# %% [markdown]
# #### Image Visualization

# %%
plt.figure(figsize=(10,8))
for i,img in enumerate(os.listdir('Train/background')[:16]):
    plt.subplot(4,4,i+1)
    plt.title('background')
    img = cv2.imread('Train/background/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %% [markdown]
# #### Crop Images

# %%
plt.figure(figsize=(10,8))
for i,img in enumerate(os.listdir('Train/crop')[0:16]):
    plt.subplot(4,4,i+1)
    plt.title('crop')
    img = cv2.imread('Train/crop/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %% [markdown]
# #### Weed Images

# %%
plt.figure(figsize=(10,8))

for i,img in enumerate(os.listdir('Train/weed')[0:16]):
    plt.subplot(4,4,i+1)
    plt.title('weed')
    img = cv2.imread('Train/weed/'+img)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
plt.show()
